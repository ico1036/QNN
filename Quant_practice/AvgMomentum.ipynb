# %%
import pandas as pd
import numpy as np
import matplotlib
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('REITUS.csv')
print(data[:13])
# Out:
#           Date    Open    High     Low   Close   Volume
# 0   2015-06-30  17.025  17.515  15.575  15.689  5127617
# 1   2015-07-31  15.856  17.456  15.363  17.456   455550
# 2   2015-08-31  17.567  18.201  14.847  15.378   862914
# 3   2015-09-30  14.940  16.384  14.366  15.967   198424
# 4   2015-10-31  16.085  18.701  16.069  17.945   392862
# 5   2015-11-30  18.135  18.635  16.373  17.698   124854
# 6   2015-12-31  18.006  18.673  16.223  18.511   180071
# 7   2016-01-31  17.760  18.596  14.929  16.769   206247
# 8   2016-02-29  16.901  17.299  14.494  16.959   143433
# 9   2016-03-31  17.047  20.281  17.039  20.281   354007
# 10  2016-04-30  20.178  20.486  18.825  19.176    74975
# 11  2016-05-31  19.785  21.658  19.029  20.050   245806
# 12  2016-06-30  20.385  22.629  20.050  22.629   132436

# %%
open_data = pd.DataFrame.copy(data)
open_data = open_data.drop(columns=['High','Low','Close','Volume'])
print(open_data)
# Out:
#           Date    Open
# 0   2015-06-30  17.025
# 1   2015-07-31  15.856
# 2   2015-08-31  17.567
# 3   2015-09-30  14.940
# 4   2015-10-31  16.085
# 5   2015-11-30  18.135
# 6   2015-12-31  18.006
# 7   2016-01-31  17.760
# 8   2016-02-29  16.901
# 9   2016-03-31  17.047
# 10  2016-04-30  20.178
# 11  2016-05-31  19.785
# 12  2016-06-30  20.385
# 13  2016-07-31  23.266
# 14  2016-08-31  24.871
# 15  2016-09-30  23.015
# 16  2016-10-31  21.588
# 17  2016-11-30  19.235
# 18  2016-12-31  18.360
# 19  2017-01-31  20.565
# 20  2017-02-28  20.405
# 21  2017-03-31  21.765
# 22  2017-04-30  20.705
# 23  2017-05-31  20.721
# 24  2017-06-30  20.533
# 25  2017-07-31  20.497
# 26  2017-08-31  21.803
# 27  2017-09-30  21.758
# 28  2017-10-31  21.649
# 29  2017-11-30  21.092
# 30  2017-12-31  22.049
# 31  2018-01-31  21.737
# 32  2018-02-28  19.555
# 33  2018-03-31  17.160
# 34  2018-04-30  17.653
# 35  2018-05-31  18.673
# 36  2018-06-30  20.145
# 37  2018-07-31  21.369
# 38  2018-08-31  21.657
# 39  2018-09-30  22.929
# 40  2018-10-31  21.482
# 41  2018-11-30  20.505
# 42  2018-12-31  22.422
# 43  2019-01-31  18.038
# 44  2019-02-28  22.579
# 45  2019-03-31  22.550
# 46  2019-04-30  24.403
# 47  2019-05-31  24.472
# 48  2019-06-30  24.530
# 49  2019-07-31  25.103
# 50  2019-08-31  25.320
# 51  2019-09-30  27.336
# 52  2019-10-31  28.203
# 53  2019-11-30  29.460
# 54  2019-12-31  27.949
# 55  2020-01-31  26.856
# 56  2020-02-29  28.612

# %%
def makeScore(date):
    
    sum=0
    for i in range(12):
        if (open_data.loc[date]['Open'] - open_data.loc[date-i]['Open']) >0:
            sum += 1
    return sum / 12 * 100

# %%
print(makeScore(11))
print(len(open_data))
# Out:
# 83.33333333333334
# 57

# %%
Score_list = []
for i in range(11,len(open_data)):
    Score_list.append(makeScore(i))

# %%
Score_sr = pd.Series(Score_list)

# %%
display(Score_sr)
# Out:
# 0     83.333333
# 1     91.666667
# 2     91.666667
# 3     91.666667
# 4     75.000000
# 5     66.666667
# 6     33.333333
# 7     25.000000
# 8     58.333333
# 9     50.000000
# 10    66.666667
# 11    50.000000
# 12    50.000000
# 13    25.000000
# 14    25.000000
# 15    83.333333
# 16    75.000000
# 17    66.666667
# 18    58.333333
# 19    91.666667
# 20    58.333333
# 21     0.000000
# 22     0.000000
# 23     8.333333
# 24    16.666667
# 25    33.333333
# 26    50.000000
# 27    66.666667
# 28    91.666667
# 29    58.333333
# 30    41.666667
# 31    83.333333
# 32    16.666667
# 33    83.333333
# 34    75.000000
# 35    91.666667
# 36    91.666667
# 37    91.666667
# 38    91.666667
# 39    91.666667
# 40    91.666667
# 41    91.666667
# 42    91.666667
# 43    75.000000
# 44    58.333333
# 45    83.333333
# dtype: float64

# %%
date_sr = open_data[11:]['Date']

# %%
print(date_sr)
# Out:
# 11    2016-05-31
# 12    2016-06-30
# 13    2016-07-31
# 14    2016-08-31
# 15    2016-09-30
# 16    2016-10-31
# 17    2016-11-30
# 18    2016-12-31
# 19    2017-01-31
# 20    2017-02-28
# 21    2017-03-31
# 22    2017-04-30
# 23    2017-05-31
# 24    2017-06-30
# 25    2017-07-31
# 26    2017-08-31
# 27    2017-09-30
# 28    2017-10-31
# 29    2017-11-30
# 30    2017-12-31
# 31    2018-01-31
# 32    2018-02-28
# 33    2018-03-31
# 34    2018-04-30
# 35    2018-05-31
# 36    2018-06-30
# 37    2018-07-31
# 38    2018-08-31
# 39    2018-09-30
# 40    2018-10-31
# 41    2018-11-30
# 42    2018-12-31
# 43    2019-01-31
# 44    2019-02-28
# 45    2019-03-31
# 46    2019-04-30
# 47    2019-05-31
# 48    2019-06-30
# 49    2019-07-31
# 50    2019-08-31
# 51    2019-09-30
# 52    2019-10-31
# 53    2019-11-30
# 54    2019-12-31
# 55    2020-01-31
# 56    2020-02-29
# Name: Date, dtype: object

# %%
plt.rc('xtick',labelsize=10)
plt.rc('ytick',labelsize=20)
plt.xticks(rotation=90)
plt.rcParams["figure.figsize"] = (60,10)

plt.plot(date_sr[-100:],Score_sr[-100:],'-o',color='royalblue',label='Avergae Momentum Score')

plt.xlabel('Date',fontsize=25)
plt.ylabel('Score[%]',fontsize=25)
plt.axhline(y=50,color='r')
plt.legend(prop={'size':15})

#plt.xscale('log')
#plt.yscale('log')

plt.grid(which='major', linestyle='--')

plt.tight_layout()
plt.show()
plt.savefig('REIT_momSc.png')
plt.close()
