# %%
import FinanceDataReader as fdr
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
sns.set(rc={'figure.figsize':(11,4)})

# %%
ETF_list = [
  ["SPY", "SPY"],
  ["TLT", "TLT"],
  ["ks11", "KS11"],
  ["IAU", "IAU"],
  ["SCHP", "SCHP"],
  ["btc", "BTC/KRW"],
  ["QQQ", "QQQ"]
]

# %%
def get_df(asset_list):
    df_list = [fdr.DataReader(code, '2008-01-01', '2021-01-08')['Close'] for name, code in asset_list]
    df = pd.concat(df_list, axis=1)
    df.columns = [name for name, code in asset_list]
    print(df)
    return df

# %% [markdown]
# ---
# ## 1. Return analysis

# %%
def log_return(df):
    return np.log(df / df.shift(1)) * 100

# %%
ETF_df = get_df(ETF_list)
# Out:
#                SPY     TLT     ks11    IAU   SCHP         btc     QQQ
# Date
# 2008-01-02  144.93     NaN  1853.45   8.49    NaN         NaN     NaN
# 2008-01-03  144.86     NaN  1852.73   8.56    NaN         NaN     NaN
# 2008-01-04  141.31     NaN  1863.90   8.53    NaN         NaN     NaN
# 2008-01-07  141.19     NaN  1831.14   8.49    NaN         NaN     NaN
# 2008-01-08  138.91     NaN  1826.23   8.69    NaN         NaN     NaN
# ...            ...     ...      ...    ...    ...         ...     ...
# 2020-11-26     NaN     NaN  2625.91    NaN    NaN  19248000.0     NaN
# 2020-11-27  363.67  160.22  2633.45  17.04  61.46  19119000.0  299.01
# 2020-11-28     NaN     NaN      NaN    NaN    NaN  19480000.0     NaN
# 2020-11-29     NaN     NaN      NaN    NaN    NaN  20002000.0     NaN
# 2020-11-30  362.06  160.02  2591.34  16.95  61.55  21302000.0  299.62
#
# [3722 rows x 7 columns]

# %%
ETF_return = log_return(ETF_df)

# %%
## Log returns of stock & ETF
sns.set(rc={'figure.figsize':(11,4)})
ETF_return.plot()
plt.ylabel("Log Returns")
# Out:
# Text(0, 0.5, 'Log Returns')

# %%
## Cumulative returns
plt.close()
sns.set(rc={'figure.figsize':(11,4)})
np.cumsum(ETF_return).plot()
plt.ylabel("Cumulative returns")
# Out:
# Text(0, 0.5, 'Cumulative returns')

# %%
def sharp(rt):
    return rt / rt.std()

# %%
## Sharp
sns.set(rc={'figure.figsize':(11,4)})
sharp(ETF_return).loc['2020'].plot()
plt.ylabel("sharp")

print("#### Mean sharp ####")
print(ETF_return.mean() / ETF_return.std())
print("#### Peack sharp ####")
sharp(ETF_return).max()
# Out:
# #### Mean sharp ####
# SPY     0.024058
# TLT     0.025295
# ks11    0.016588
# IAU     0.018075
# SCHP    0.065813
# btc     0.035149
# QQQ     0.068253
# dtype: float64
# #### Peack sharp ####
# SPY     10.376661
# TLT      8.466321
# ks11     9.101464
# IAU      9.522303
# SCHP    11.704131
# btc      6.199251
# QQQ      6.162764
# dtype: float64

# %% [markdown]
# - Sharp 에 mean 값과 return 의 모든 값을 넣었을 때의 최대값 과 괴리가 심함 어떤게 맞는지
# ---
#
# ## 2. Resample & Interpolate data

# %%
def resample(df,mode="Linear_interpolate"):
    resample_df = df.resample('D').mean()
    if mode == "Linear_interpolate":
        rsp_df = resample_df.interpolate(method='values')
    else:
        rsp_df = resample_df
    return rsp_df

# %%
def minMaxScale(obj):
    return (obj - obj.min()) / (obj.max() - obj.min())

# %%
billed_rsp_df = resample(ETF_df)
normed_df = minMaxScale(billed_rsp_df)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
normed_df['SPY'].loc['2010':].plot()
#normed_df['TLT'].loc['2019':].plot()
normed_df['QQQ'].loc['2010':].plot()
#normed_df['btc'].loc['2019':].plot()
plt.legend()

# %%
import scipy.stats as stats

# %%
for s1 in ETF_list:
    l1=[]
    for s2 in ETF_list:
        r,_ = stats.pearsonr(billed_rsp_df.dropna()[s1[0]], billed_rsp_df.dropna()[s2[0]])
        l1.append(r)
        
        print('Corr of {0},{1} = {2}'.format(s1[0],s2[0],r))
# Out:
# Corr of SPY,SPY = 1.0
# Corr of SPY,TLT = 0.624533550913956
# Corr of SPY,ks11 = 0.18843438607001461
# Corr of SPY,IAU = 0.7516711045935944
# Corr of SPY,SCHP = 0.7888078088997263
# Corr of SPY,btc = 0.4572890485940126
# Corr of SPY,QQQ = 0.9085332033034249
# Corr of TLT,SPY = 0.624533550913956
# Corr of TLT,TLT = 1.0
# Corr of TLT,ks11 = -0.2924025329135261
# Corr of TLT,IAU = 0.941696831458831
# Corr of TLT,SCHP = 0.9408282052653338
# Corr of TLT,btc = 0.43064793885346275
# Corr of TLT,QQQ = 0.8212190050969351
# Corr of ks11,SPY = 0.18843438607001461
# Corr of ks11,TLT = -0.2924025329135261
# Corr of ks11,ks11 = 1.0
# Corr of ks11,IAU = -0.06455908794271223
# Corr of ks11,SCHP = -0.02477807641339537
# Corr of ks11,btc = 0.34898516360176024
# Corr of ks11,QQQ = 0.07856574846028395
# Corr of IAU,SPY = 0.7516711045935944
# Corr of IAU,TLT = 0.941696831458831
# Corr of IAU,ks11 = -0.06455908794271223
# Corr of IAU,IAU = 1.0
# Corr of IAU,SCHP = 0.9707826904804109
# Corr of IAU,btc = 0.4786104385274413
# Corr of IAU,QQQ = 0.9151763673140297
# Corr of SCHP,SPY = 0.7888078088997263
# Corr of SCHP,TLT = 0.9408282052653338
# Corr of SCHP,ks11 = -0.02477807641339537
# Corr of SCHP,IAU = 0.9707826904804109
# Corr of SCHP,SCHP = 1.0
# Corr of SCHP,btc = 0.5540275384735801
# Corr of SCHP,QQQ = 0.9276473154557494
# Corr of btc,SPY = 0.4572890485940126
# Corr of btc,TLT = 0.43064793885346275
# Corr of btc,ks11 = 0.34898516360176024
# Corr of btc,IAU = 0.4786104385274413
# Corr of btc,SCHP = 0.5540275384735801
# Corr of btc,btc = 1.0
# Corr of btc,QQQ = 0.43721249403109425
# Corr of QQQ,SPY = 0.9085332033034249
# Corr of QQQ,TLT = 0.8212190050969351
# Corr of QQQ,ks11 = 0.07856574846028395
# Corr of QQQ,IAU = 0.9151763673140297
# Corr of QQQ,SCHP = 0.9276473154557494
# Corr of QQQ,btc = 0.43721249403109425
# Corr of QQQ,QQQ = 0.9999999999999998

# %% [markdown]
# ---

# %% [markdown]
# ### case study 1: Low USD hedging
# 달러의 헷징 수단으로 BCI,PDBC 가 좋으나 변동성과 수익률을 보면 잠깐 넣었다가 빼는게 답

# %%
USD_COM=[
    ["USD/KRW","USD/KRW"],
    ["GSG","GSG"],
    ["BCI","BCI"],
    ["DBC","DBC"],
    ["PDBC","PDBC"]
]

# %%
USD_COM_df = get_df(USD_COM)
# Out:
#             USD/KRW    GSG    BCI    DBC   PDBC
# Date
# 2008-01-01   936.10    NaN    NaN    NaN    NaN
# 2008-01-02   936.95  54.66    NaN  32.43    NaN
# 2008-01-03   936.50  54.66    NaN  32.68    NaN
# 2008-01-04   938.45  54.30    NaN  32.49    NaN
# 2008-01-07   940.70  52.68    NaN  31.90    NaN
# ...             ...    ...    ...    ...    ...
# 2020-11-24  1110.24  11.61  21.02  13.93  14.51
# 2020-11-25  1106.21  11.70  21.08  14.05  14.61
# 2020-11-26  1105.57    NaN    NaN    NaN    NaN
# 2020-11-27  1104.43  11.69  21.07  14.02  14.59
# 2020-11-30  1109.32  11.65  21.02  13.94  14.50
#
# [3395 rows x 5 columns]

# %%
USD_COM_return =log_return(USD_COM_df)
USD_COM_rsp = resample(USD_COM_df)
USD_COM_normed = minMaxScale(USD_COM_rsp)

# %%
plt.close()
sns.set(rc={'figure.figsize':(11,4)})
USD_COM_normed.plot()

# %%
print(" ### RISK ###")
print(USD_COM_return.std())
print(" ### Sharp ###")
print(USD_COM_return.mean())
# Out:
#  ### RISK ###
# USD/KRW    0.739969
# GSG        1.509332
# BCI        0.890014
# DBC        1.209572
# PDBC       1.070246
# dtype: float64
#  ### Sharp ###
# USD/KRW    0.004643
# GSG       -0.034056
# BCI       -0.011875
# DBC       -0.018371
# PDBC      -0.013035
# dtype: float64

# %%
plt.close()
sns.set(rc={'figure.figsize':(11,4)})
USD_COM_return.plot()

# %%
plt.close()
sns.set(rc={'figure.figsize':(11,4)})
np.cumsum(USD_COM_return).loc['2019':].plot()

# %% [markdown]
# ---
# ### case study 2: Portfolio building

# %%
Portfolio_list = [
  ["TLT", "TLT"],
  ["ks11", "KS11"],
  ["IAU", "IAU"],
  ["SCHP", "SCHP"],
  ["btc", "BTC/KRW"],
  ["QQQ", "QQQ"],
  ["BCI","BCI"]
]

# %%
PF_df = get_df(Portfolio_list)
# Out:
#                TLT     ks11    IAU   SCHP         btc     QQQ    BCI
# Date
# 2008-01-02     NaN  1853.45   8.49    NaN         NaN     NaN    NaN
# 2008-01-03     NaN  1852.73   8.56    NaN         NaN     NaN    NaN
# 2008-01-04     NaN  1863.90   8.53    NaN         NaN     NaN    NaN
# 2008-01-07     NaN  1831.14   8.49    NaN         NaN     NaN    NaN
# 2008-01-08     NaN  1826.23   8.69    NaN         NaN     NaN    NaN
# ...            ...      ...    ...    ...         ...     ...    ...
# 2021-01-04  157.54  2944.45  18.55  62.18  36499000.0  309.31  21.96
# 2021-01-05  156.37  2990.57  18.59  62.12  37962000.0  311.86  22.49
# 2021-01-06  153.16  2968.21  18.30  61.95  40731000.0  307.54  22.46
# 2021-01-07  151.81  3031.68  18.24  61.93  44575000.0  314.98  22.41
# 2021-01-08     NaN  3152.18    NaN    NaN  47226000.0     NaN    NaN
#
# [3761 rows x 7 columns]

# %%
PF_df_return = log_return(PF_df)

# %%
plt.close()
sns.set(rc={'figure.figsize':(11,4)})
np.cumsum(PF_df_return)[['TLT','IAU','ks11','SCHP','QQQ']].loc[:'2020'].plot()

# %% [markdown]
# 1) -- 인플레이션 헷징 + 디플레이션 헷징 --
#  - TLT 2
#  - SCHP 8
#
# 2) -- 주식 --
#  - ks11 3
#  - QQQ  7
#
# 3) -- 금/암호화폐 --
#  - IAU 9
#  - btc 1
#
#
# 4) -- 디플레이션 헷징--
#  - USD 4
#  - WON 6
#  ---
#  - 1) 4
#  - 2) 3
#  - 3) 1
#  - 4) 2

# %%
def Numb1(rat):
    TLT= rat*0.
    SCHP = rat*1.0
    print("TLT: ",TLT)
    print("SCHHP: ",SCHP)
    return(TLT,SCHP)

def Numb2(rat):
    KOSPI= rat*0.3
    QQQ = rat*0.7
    print("KOSPI: ",KOSPI)
    print("QQQ: ",QQQ)
    return(KOSPI,QQQ)

def Numb3(rat):
    IAU = rat*0.9
    BTC = rat*0.1
    print("IAU: ",IAU)
    print("BTC: ",BTC)
    return(IAU,BTC)

def Numb4(rat):
    USD= rat*0.4
    WON = rat*0.6
    print("USD: ",USD)
    print("WON: ",WON)
    return(USD,WON)

# %%
w_TLT,w_SCHP = Numb1(4)
w_ks11,w_QQQ = Numb2(3)
w_IAU,w_BTC = Numb3(1)
w_USD,w_WON = Numb4(2)
# Out:
# TLT:  0.0
# SCHHP:  4.0
# KOSPI:  0.8999999999999999
# QQQ:  2.0999999999999996
# IAU:  0.9
# BTC:  0.1
# USD:  0.8
# WON:  1.2

# %%
def Beta_Inv(Seed):
    Numb1(Seed*0.4)
    Numb2(Seed*0.3)
    Numb3(Seed*0.1)
    Numb4(Seed*0.2)

Beta_Inv(400)
# Out:
# TLT:  0.0
# SCHHP:  160.0
# KOSPI:  36.0
# QQQ:  84.0
# IAU:  36.0
# BTC:  4.0
# USD:  32.0
# WON:  48.0

# %%
print(Beta_Inv(4597368))
# Out:
# TLT:  0.0
# SCHHP:  1838947.2000000002
# KOSPI:  413763.11999999994
# QQQ:  965447.2799999999
# IAU:  413763.12000000005
# BTC:  45973.68000000001
# USD:  367789.44000000006
# WON:  551684.16
# None

# %%
plt.figure(figsize=(12, 12))
ratio = [w_TLT,w_SCHP,w_ks11,w_QQQ,w_IAU,w_BTC,w_USD,w_WON]
labels = ['TLT','SCHP','KOSPI','QQQ','Gold','BitCoin','USD','Won']
plt.pie(ratio, labels=labels, autopct='%.1f%%')
plt.show()

# %%
PF_df_return.columns
# Out:
# Index(['TLT', 'ks11', 'IAU', 'SCHP', 'btc', 'QQQ', 'BCI'], dtype='object')

# %%
TLT_weighted = PF_df_return['TLT'] * w_TLT
SCHP_weighted = PF_df_return['SCHP'] * w_SCHP
KOSPI_weighted = PF_df_return['ks11'] * w_ks11
QQQ_weighted = PF_df_return['QQQ'] * w_QQQ
IAU_weighted = PF_df_return['IAU'] * w_IAU
BTC_weighted = PF_df_return['btc'] * w_BTC

# %%
Portfolio_return =  TLT_weighted + SCHP_weighted + KOSPI_weighted + QQQ_weighted + IAU_weighted + BTC_weighted

# %%
print(Portfolio_return.loc['2019'])
print(ETF_return.loc['2019'])
# Out:
# Date
# 2019-01-01         NaN
# 2019-01-02         NaN
# 2019-01-03   -4.586346
# 2019-01-04    7.905105
# 2019-01-05         NaN
#                 ...
# 2019-12-27    0.115693
# 2019-12-28         NaN
# 2019-12-29         NaN
# 2019-12-30         NaN
# 2019-12-31         NaN
# Length: 365, dtype: float64
#                  SPY       TLT      ks11       IAU      SCHP       btc  \
# Date
# 2019-01-01       NaN       NaN       NaN       NaN       NaN  2.120720
# 2019-01-02       NaN       NaN       NaN       NaN       NaN  1.297215
# 2019-01-03 -2.415215  1.131519 -0.814251  0.890334  0.616651 -1.460557
# 2019-01-04  3.294700 -1.164271  0.826688 -0.727864 -0.261145  0.628567
# 2019-01-05       NaN       NaN       NaN       NaN       NaN -0.278875
# ...              ...       ...       ...       ...       ...       ...
# 2019-12-27 -0.024775  0.109294  0.285316 -0.069228  0.017663  0.274447
# 2019-12-28       NaN       NaN       NaN       NaN       NaN  0.392461
# 2019-12-29       NaN       NaN       NaN       NaN       NaN  0.768552
# 2019-12-30       NaN       NaN       NaN       NaN       NaN -1.770589
# 2019-12-31  0.242636 -0.984217       NaN  0.068989 -0.052961 -0.396421
#
#                  QQQ
# Date
# 2019-01-01       NaN
# 2019-01-02       NaN
# 2019-01-03 -3.321605
# 2019-01-04  4.189471
# 2019-01-05       NaN
# ...              ...
# 2019-12-27 -0.084230
# 2019-12-28       NaN
# 2019-12-29       NaN
# 2019-12-30       NaN
# 2019-12-31  0.188315
#
# [365 rows x 7 columns]

# %%
plt.close()
sns.set(rc={'figure.figsize':(11,4)})
(np.cumsum(Portfolio_return).loc['2018':]).plot(label='JW_capital')
(np.cumsum(ETF_return['SPY']).loc['2018':]).plot(label='S&P')

plt.legend()

# %%
print("=== Mean Sharp index:  Returns / Risk ===")
print("JW capital",Portfolio_return.loc['2019-12':].mean() / Portfolio_return.loc['2019-12':].std())
print("S&P index",ETF_return['SPY'].loc['2019-12':].mean() / ETF_return['SPY'].loc['2019-12':].std())
# Out:
# === Mean Sharp index:  Returns / Risk ===
# JW capital 0.1270841297475993
# S&P index 0.04740135170840798
